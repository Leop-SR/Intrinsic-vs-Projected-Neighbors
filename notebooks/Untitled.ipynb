# %%
import sys 
import numpy as np
import pandas as pd
print(sys.executable)
np.arange(5)
# Out:
# C:\Users\sanru\Documents\dev\Python\Projects\Intrinsic-vs-Projected-Neighbors\.venv\Scripts\python.exe
# array([0, 1, 2, 3, 4])
